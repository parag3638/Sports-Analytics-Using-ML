# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.expand_frame_repr',False)
pd.set_option('max_colwidth',-1)

# %%
deliveries = pd.read_csv("deliveries.csv")

# %%
df= deliveries.copy()
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind fielder
# 0  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     1     DA Warner  S Dhawan    TS Mills  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN
# 1  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     2     DA Warner  S Dhawan    TS Mills  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN
# 2  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     3     DA Warner  S Dhawan    TS Mills  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN
# 3  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     4     DA Warner  S Dhawan    TS Mills  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN
# 4  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     5     DA Warner  S Dhawan    TS Mills  0              2          0         0            0            0             0             2           2           NaN              NaN            NaN

# %%
for i in range(len(df)):
    if((df['over'][i])<=6):
        df['phase'][i]='powerplay';   
    elif((df['over'][i])>6 and (df['over'][i])<16):
        df['phase'][i]='middle';   
    elif((df['over'][i])>15 and (df['over'][i])<=20):
        df['phase'][i]='death'; 
    else:
        df['phase'][i]='super';

# for i in range(250):
#     if(df['over'][i]<=6):
#         print(df['over'][i],'powerplay')   
#     elif(df['over'][i]>6 and df['over'][i]<16):
#         print(df['over'][i],'power')   
#     elif(df['over'][i]>=16 and df['over'][i]<=20):
#         print(df['over'][i],"ay")   
#     else:
#         print(df['over'][i],'po')

# %%
df.head(120)
# Out:
#      match_id  inning         batting_team                 bowling_team  over  ball       batsman   non_striker       bowler  is_super_over  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs player_dismissed dismissal_kind        fielder      phase
# 0    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     1     DA Warner     S Dhawan      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 1    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     2     DA Warner     S Dhawan      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 2    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     3     DA Warner     S Dhawan      TS Mills     0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 3    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     4     DA Warner     S Dhawan      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 4    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     5     DA Warner     S Dhawan      TS Mills     0              2          0         0            0            0             0             2           2           NaN              NaN            NaN            powerplay
# 5    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     6     S Dhawan      DA Warner     TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 6    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  1     7     S Dhawan      DA Warner     TS Mills     0              0          0         1            0            0             0             1           1           NaN              NaN            NaN            powerplay
# 7    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     1     S Dhawan      DA Warner     A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 8    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     2     DA Warner     S Dhawan      A Choudhary  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 9    1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     3     DA Warner     S Dhawan      A Choudhary  0              0          0         0            1            0             0             1           1           NaN              NaN            NaN            powerplay
# 10   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     4     DA Warner     S Dhawan      A Choudhary  0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            powerplay
# 11   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     5     DA Warner     S Dhawan      A Choudhary  0              0          0         0            0            0             0             0           0           DA Warner        caught         Mandeep Singh  powerplay
# 12   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     6     MC Henriques  S Dhawan      A Choudhary  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 13   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  2     7     MC Henriques  S Dhawan      A Choudhary  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 14   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     1     S Dhawan      MC Henriques  TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 15   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     2     MC Henriques  S Dhawan      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 16   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     3     MC Henriques  S Dhawan      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 17   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     4     MC Henriques  S Dhawan      TS Mills     0              0          0         0            0            0             3             0           3           NaN              NaN            NaN            powerplay
# 18   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     5     S Dhawan      MC Henriques  TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 19   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  3     6     MC Henriques  S Dhawan      TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 20   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     1     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 21   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     2     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 22   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     3     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 23   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     4     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 24   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     5     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 25   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  4     6     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 26   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     1     S Dhawan      MC Henriques  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 27   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     2     MC Henriques  S Dhawan      S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 28   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     3     S Dhawan      MC Henriques  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 29   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     4     MC Henriques  S Dhawan      S Aravind    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            powerplay
# 30   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     5     MC Henriques  S Dhawan      S Aravind    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 31   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  5     6     MC Henriques  S Dhawan      S Aravind    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 32   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     1     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 33   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     2     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 34   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     3     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            powerplay
# 35   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     4     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 36   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     5     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            powerplay
# 37   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  6     6     S Dhawan      MC Henriques  SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            powerplay
# 38   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     1     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 39   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     2     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 40   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     3     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 41   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     4     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 42   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     5     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 43   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  7     6     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 44   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     1     S Dhawan      MC Henriques  TM Head      0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 45   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     2     MC Henriques  S Dhawan      TM Head      0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 46   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     3     S Dhawan      MC Henriques  TM Head      0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 47   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     4     MC Henriques  S Dhawan      TM Head      0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            middle
# 48   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     5     MC Henriques  S Dhawan      TM Head      0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 49   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  8     6     S Dhawan      MC Henriques  TM Head      0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 50   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     1     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 51   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     2     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 52   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     3     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 53   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     4     S Dhawan      MC Henriques  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 54   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     5     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 55   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  9     6     MC Henriques  S Dhawan      YS Chahal    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 56   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    1     S Dhawan      MC Henriques  A Choudhary  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 57   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    2     S Dhawan      MC Henriques  A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 58   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    3     MC Henriques  S Dhawan      A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 59   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    4     S Dhawan      MC Henriques  A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 60   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    5     MC Henriques  S Dhawan      A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 61   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  10    6     S Dhawan      MC Henriques  A Choudhary  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 62   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    1     MC Henriques  S Dhawan      STR Binny    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 63   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    2     S Dhawan      MC Henriques  STR Binny    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 64   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    3     S Dhawan      MC Henriques  STR Binny    0              0          0         0            0            0             0             0           0           S Dhawan         caught         Sachin Baby    middle
# 65   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    4     MC Henriques  Yuvraj Singh  STR Binny    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 66   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    5     Yuvraj Singh  MC Henriques  STR Binny    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 67   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  11    6     Yuvraj Singh  MC Henriques  STR Binny    0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 68   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    1     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 69   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    2     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 70   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    3     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 71   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    4     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 72   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    5     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 73   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  12    6     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 74   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    1     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 75   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    2     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            middle
# 76   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    3     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 77   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    4     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 78   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    5     Yuvraj Singh  MC Henriques  A Choudhary  0              1          0         0            0            0             0             1           1           NaN              NaN            NaN            middle
# 79   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    6     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            middle
# 80   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  13    7     Yuvraj Singh  MC Henriques  A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 81   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    1     Yuvraj Singh  MC Henriques  SR Watson    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 82   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    2     Yuvraj Singh  MC Henriques  SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 83   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    3     MC Henriques  Yuvraj Singh  SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 84   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    4     Yuvraj Singh  MC Henriques  SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 85   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    5     MC Henriques  Yuvraj Singh  SR Watson    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            middle
# 86   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  14    6     MC Henriques  Yuvraj Singh  SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 87   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    1     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            middle
# 88   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    2     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 89   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    3     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            middle
# 90   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    4     Yuvraj Singh  MC Henriques  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 91   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    5     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            middle
# 92   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  15    6     MC Henriques  Yuvraj Singh  S Aravind    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            middle
# 93   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    1     MC Henriques  Yuvraj Singh  YS Chahal    0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            death
# 94   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    2     MC Henriques  Yuvraj Singh  YS Chahal    0              0          0         0            0            0             0             0           0           MC Henriques     caught         Sachin Baby    death
# 95   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    3     Yuvraj Singh  DJ Hooda      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 96   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    4     DJ Hooda      Yuvraj Singh  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 97   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    5     Yuvraj Singh  DJ Hooda      YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 98   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  16    6     DJ Hooda      Yuvraj Singh  YS Chahal    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 99   1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    1     DJ Hooda      Yuvraj Singh  TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 100  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    2     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            death
# 101  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    3     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            death
# 102  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    4     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 103  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    5     DJ Hooda      Yuvraj Singh  TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            death
# 104  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  17    6     DJ Hooda      Yuvraj Singh  TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 105  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    1     DJ Hooda      Yuvraj Singh  A Choudhary  0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            death
# 106  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    2     DJ Hooda      Yuvraj Singh  A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 107  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    3     Yuvraj Singh  DJ Hooda      A Choudhary  0              1          0         0            0            0             0             1           1           NaN              NaN            NaN            death
# 108  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    4     Yuvraj Singh  DJ Hooda      A Choudhary  0              1          0         0            0            0             0             1           1           NaN              NaN            NaN            death
# 109  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    5     Yuvraj Singh  DJ Hooda      A Choudhary  0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            death
# 110  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    6     Yuvraj Singh  DJ Hooda      A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 111  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    7     DJ Hooda      Yuvraj Singh  A Choudhary  0              0          0         0            0            0             2             0           2           NaN              NaN            NaN            death
# 112  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  18    8     DJ Hooda      Yuvraj Singh  A Choudhary  0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 113  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    1     DJ Hooda      Yuvraj Singh  TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 114  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    2     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             4             0           4           NaN              NaN            NaN            death
# 115  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    3     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             6             0           6           NaN              NaN            NaN            death
# 116  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    4     Yuvraj Singh  DJ Hooda      TS Mills     0              0          0         0            0            0             0             0           0           Yuvraj Singh     bowled         NaN            death
# 117  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    5     BCJ Cutting   DJ Hooda      TS Mills     0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death
# 118  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  19    6     DJ Hooda      BCJ Cutting   TS Mills     0              0          0         0            0            0             0             0           0           NaN              NaN            NaN            death
# 119  1         1       Sunrisers Hyderabad  Royal Challengers Bangalore  20    1     BCJ Cutting   DJ Hooda      SR Watson    0              0          0         0            0            0             1             0           1           NaN              NaN            NaN            death

# %%
# df['isdot'] = df['batsman_runs'].apply(lambda x:1 if x==0 else 0)
# df['isOne'] = df['batsman_runs'].apply(lambda x:1 if x==1 else 0)
# df['isTwo'] = df['batsman_runs'].apply(lambda x:1 if x==2 else 0)
# df['isThree'] = df['batsman_runs'].apply(lambda x:1 if x==3 else 0)
# df['isFour'] = df['batsman_runs'].apply(lambda x:1 if x==4 else 0)
# df['isSix'] = df['batsman_runs'].apply(lambda x:1 if x==6 else 0)
# df['ispowerplay']=df['over'].apply(lambda x:1 if x<=6 else 0)
# df['ismiddle']=df['over'].apply(lambda x:1 if (x>6 and x<16) else 0)
# df['isdeath']=df['over'].apply(lambda x:1 if (x>=16 and x<20) else 0)


# #len(df['batsman'].unique())

# #df.groupby(df.batsman)['batsman_runs'].sum()

# #df.groupby(['batsman','match_id'])['batsman_runs'].sum()

# # Warner Individual score in all matches
# # 3 things= df,groupby,aggregate functions 
# #df[df.batsman=='DA Warner'].groupby(['batsman','match_id'])['batsman_runs'].sum()

# # Warner total score in all matches
# #(df[df.batsman=='DA Warner'].groupby(['batsman','match_id'])['batsman_runs'].sum()).sum()

# # All Individual Score in a match
# # Just by changing the order of group by differs the result totally opposite
# #df.groupby(['match_id','batsman'])['batsman_runs'].sum()

# # Batsman sorted according to runs scored
# #pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).sort_values(by="batsman_runs",ascending=False).head(5)

# #df[df.batting_team=="Sunrisers Hyderabad"].head(2)

# #analyse 6th ball of each over
# #df[df.ball==6].head(2)

# #analyse 20th over of each match
# #df[df.over==20].tail(2)

# pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).head(3).index
# runs=(pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index()).rename(columns={'batsman_runs':'runs'})
# #(df.groupby(['batsman'])['match_id'].unique())
# #df.groupby(['batsman'])['match_id'].count()
# balls=pd.DataFrame(df.groupby(['batsman'])['match_id'].count()).reset_index().rename(columns={'match_id':'balls'})
# innings=pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x: len(list(np.unique(x))))).reset_index().rename(columns={'match_id':'innings'})
# dismissals=pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns={'player_dismissed':'dismissals'})
# sixes=(pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index()).rename(columns={'isSix':'Sixes'})
# fours=(pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index()).rename(columns={'isFour':'fours'})

# mega=pd.merge(innings,runs,on="batsman").merge(balls,on="batsman").merge(dismissals,on="batsman").merge(sixes,on="batsman").merge(fours,on="batsman")

# #mega.head()

# mega['RPI']=mega.apply(lambda x: (x['runs']/x['innings']),axis=1)

# %%
def ByInnings(df, current_innings):
    
    df = df[df.inning==current_innings]
    df.reset_index(inplace=True, drop= True)

    df['isdot'] = df['batsman_runs'].apply(lambda x:1 if x==0 else 0)
    df['isOne'] = df['batsman_runs'].apply(lambda x:1 if x==1 else 0)
    df['isTwo'] = df['batsman_runs'].apply(lambda x:1 if x==2 else 0)
    df['isThree'] = df['batsman_runs'].apply(lambda x:1 if x==3 else 0)
    df['isFour'] = df['batsman_runs'].apply(lambda x:1 if x==4 else 0)
    df['isSix'] = df['batsman_runs'].apply(lambda x:1 if x==6 else 0)
#     df['ispowerplay']=df['over'].apply(lambda x:1 if x<=6 else 0)
#     df['ismiddle']=df['over'].apply(lambda x:1 if (x>6 and x<16) else 0)
#     df['isdeath']=df['over'].apply(lambda x:1 if (x>=16 and x<20) else 0)


    
    pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).head(3).index
    runs=(pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index()).rename(columns={'batsman_runs':'runs'})
    #(df.groupby(['batsman'])['match_id'].unique())
    #df.groupby(['batsman'])['match_id'].count()
    balls=pd.DataFrame(df.groupby(['batsman'])['match_id'].count()).reset_index().rename(columns={'match_id':'balls'})
    innings=pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x: len(list(np.unique(x))))).reset_index().rename(columns={'match_id':'innings'})
    dismissals=pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns={'player_dismissed':'dismissals'})
    sixes=(pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index()).rename(columns={'isSix':'Sixes'})
    fours=(pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index()).rename(columns={'isFour':'fours'})
    powerplay=df['over'].apply(lambda x:1 if x<=6 else 0)
    middle=df['over'].apply(lambda x:1 if (x>6 and x<16) else 0)
    death=df['over'].apply(lambda x:1 if (x>=16 and x<20) else 0)
    
    
    df=pd.merge(innings,runs,on="batsman").merge(balls,on="batsman").merge(dismissals,on="batsman").merge(sixes,on="batsman").merge(fours,on="batsman")
    df['RPI']=df.apply(lambda x: (x['runs']/x['innings']),axis=1)
    df['Strike_rate']=df.apply(lambda x: (x['runs']/x['balls'])*100,axis=1)

    return df;

# %%
def ByPhase(df, phase1):
    
    df = df[df.phase==phase1]
    df.reset_index(inplace=True, drop= True)
    
    df['isdot'] = df['batsman_runs'].apply(lambda x:1 if x==0 else 0)
    df['isOne'] = df['batsman_runs'].apply(lambda x:1 if x==1 else 0)
    df['isTwo'] = df['batsman_runs'].apply(lambda x:1 if x==2 else 0)
    df['isThree'] = df['batsman_runs'].apply(lambda x:1 if x==3 else 0)
    df['isFour'] = df['batsman_runs'].apply(lambda x:1 if x==4 else 0)
    df['isSix'] = df['batsman_runs'].apply(lambda x:1 if x==6 else 0)
#     df['ispowerplay']=df['over'].apply(lambda x:1 if x<=6 else 0)
#     df['ismiddle']=df['over'].apply(lambda x:1 if (x>6 and x<16) else 0)
#     df['isdeath']=df['over'].apply(lambda x:1 if (x>=16 and x<20) else 0)


    
    pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).head(3).index
    runs=(pd.DataFrame(df.groupby(['batsman'])['batsman_runs'].sum()).reset_index()).rename(columns={'batsman_runs':'runs'})
    #(df.groupby(['batsman'])['match_id'].unique())
    #df.groupby(['batsman'])['match_id'].count()
    balls=pd.DataFrame(df.groupby(['batsman'])['match_id'].count()).reset_index().rename(columns={'match_id':'balls'})
    innings=pd.DataFrame(df.groupby(['batsman'])['match_id'].apply(lambda x: len(list(np.unique(x))))).reset_index().rename(columns={'match_id':'innings'})
    dismissals=pd.DataFrame(df.groupby(['batsman'])['player_dismissed'].count()).reset_index().rename(columns={'player_dismissed':'dismissals'})
    sixes=(pd.DataFrame(df.groupby(['batsman'])['isSix'].sum()).reset_index()).rename(columns={'isSix':'Sixes'})
    fours=(pd.DataFrame(df.groupby(['batsman'])['isFour'].sum()).reset_index()).rename(columns={'isFour':'fours'})
    powerplay=df['over'].apply(lambda x:1 if x<=6 else 0)
    middle=df['over'].apply(lambda x:1 if (x>6 and x<16) else 0)
    death=df['over'].apply(lambda x:1 if (x>=16 and x<20) else 0)
    
    
    df=pd.merge(innings,runs,on="batsman").merge(balls,on="batsman").merge(dismissals,on="batsman").merge(sixes,on="batsman").merge(fours,on="batsman")
    df['RPI']=df.apply(lambda x: (x['runs']/x['innings']),axis=1)
    df['Strike_rate']=df.apply(lambda x: (x['runs']/x['balls'])*100,axis=1)

    return df;

# %%
phase1="powerplay"
#ing1_df = ByInnings(df,1)
powerplay_df = ByPhase(df,phase1)
powerplay_df.head()
# Out:
#           batsman  innings  runs  balls  dismissals  Sixes  fours   RPI  Strike_rate
# 0  A Ashish Reddy  1        5     7      1           0      1      5.0   71.428571
# 1  A Chopra        5        27    41     2           0      4      5.4   65.853659
# 2  A Flintoff      1        14    15     0           1      1      14.0  93.333333
# 3  A Mishra        1        1     5      0           0      0      1.0   20.000000
# 4  A Mukund        1        14    16     0           0      1      14.0  87.500000

# %%
#ing2_df = ByInnings(df,2,powerplay)
phase1="middle"
middle_df = ByPhase(df,phase1)
middle_df.head()
# Out:
#           batsman  innings  runs  balls  dismissals  Sixes  fours        RPI  Strike_rate
# 0  A Ashish Reddy  5        61    41     0           5      2      12.200000  148.780488
# 1  A Chopra        3        25    32     2           0      3      8.333333   78.125000
# 2  A Flintoff      2        23    24     1           0      2      11.500000  95.833333
# 3  A Kumble        1        1     5      0           0      0      1.000000   20.000000
# 4  A Mishra        16       112   152    6           0      8      7.000000   73.684211

# %%
#player ing1_RPI ing2_RPI

# %%
# ing1_df = ing1_df[['batsman','RPI']].rename(columns={'RPI':'ing1_rpi'})
# ing2_df = ing2_df[['batsman','RPI']].rename(columns={'RPI':'ing2_rpi'})
# comb=pd.merge(ing1_df,ing2_df,on = 'batsman')

powerplay_df = powerplay_df[['batsman','Strike_rate']].rename(columns={'Strike_rate':'powerplay'})
middle_df = middle_df[['batsman','Strike_rate']].rename(columns={'Strike_rate':'middle'})
comb=pd.merge(powerplay_df,middle_df,on = 'batsman')

# %%
comb=comb[comb.middle>120]
comb=comb.reset_index()
comb.head()
# Out:
#    level_0  index       batsman   powerplay      middle
# 0  3        12     AC Blizzard   128.571429  150.000000
# 1  4        13     AC Gilchrist  128.240741  140.180587
# 2  6        17     AD Russell    230.000000  153.488372
# 3  8        28     AUK Pathan    233.333333  137.500000
# 4  9        34     BB McCullum   121.816707  126.415094

# %%
# plt.figure(figsize=(6,6))
# selected_players=['V Kohli','MS Dhoni','AB de Villiers','DA Warner','CH Gayle'];
# annotations=list(comb['batsman'])    
# plt.scatter(comb['powerplay'],comb['ing2_rpi'])
# plt.xlabel('Ings1_run')
# plt.ylabel('Ings2_run')
# plt.title("Innings_1 Runs VS Innings_2 Runs")

# for i, j in enumerate(annotations):                
#     if j in selected_players:
#         plt.annotate(j,(comb['ing1_rpi'][i],comb['ing2_rpi'][i]))
# plt.show()


# plt.figure(figsize=(16,8))
# selected_players=['V Kohli','MS Dhoni','AB de Villiers','DA Warner','CH Gayle'];
# annotations=list(comb['batsman'])    
# plt.scatter(comb['powerplay'],comb['middle'])
# plt.xlabel('Powerplay')
# plt.ylabel('Middle')
# plt.title("Powerplay Strike VS Middle Strike")

# # for i in selected_players:
# #     plt.scatter(comb['powerplay'],comb['middle'])
# for i, j in enumerate(annotations):                
#     if j in selected_players:
#         plt.annotate(j,(comb['powerplay'][i],comb['middle'][i]))           
        
        
# plt.show()
